# %%
import requests

# %%
url = 'https://odre.opendatasoft.com/api/explore/v2.1/catalog/datasets/eco2mix-national-tr/records'
params = {'limit': 5,
          'select' : 'date_heure, date, eolien, nucleaire',
          'where' : 'date >= 2026-04-27',
          'order_by' : 'date_heure DESC'}

# %%
params = {
    "select": "date_heure, consommation, nucleaire, eolien, solaire",
    "where": "date_heure < now()",
    "order_by": "date_heure desc",
    "limit": 100
}

# %%
response = requests.get(url, params=params)
data = response.json()

# %%
data
# Out:
# {'total_count': 8398,
#  'results': [{'date_heure': '2026-04-29T09:15:00+00:00',
#    'consommation': None,
#    'nucleaire': None,
#    'eolien': None,
#    'solaire': None},
#   {'date_heure': '2026-04-29T09:00:00+00:00',
#    'consommation': 47081,
#    'nucleaire': 40201,
#    'eolien': 4640,
#    'solaire': 9420},
#   {'date_heure': '2026-04-29T08:45:00+00:00',
#    'consommation': 46339,
#    'nucleaire': 40560,
#    'eolien': 4716,
#    'solaire': 8871},
#   {'date_heure': '2026-04-29T08:30:00+00:00',
#    'consommation': 46923,
#    'nucleaire': 40574,
#    'eolien': 5404,
#    'solaire': 8499},
#   {'date_heure': '2026-04-29T08:15:00+00:00',
#    'consommation': 46503,
#    'nucleaire': 40667,
#    'eolien': 5823,
#    'solaire': 7799},
#   {'date_heure': '2026-04-29T08:00:00+00:00',
#    'consommation': 46461,
#    'nucleaire': 40622,
#    'eolien': 6818,
#    'solaire': 7466},
#   {'date_heure': '2026-04-29T07:45:00+00:00',
#    'consommation': 46748,
# ...
